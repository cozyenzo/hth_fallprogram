# %%
import pandas
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression

# %%
pokemon_data = pandas.read_csv('PokemonData.csv')
print(pokemon_data)
# Out:
#      Num                   Name    Type1   Type2  HP  Attack  Defense  SpAtk  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49     65
# 1      2                Ivysaur    Grass  Poison  60      62       63     80
# 2      3               Venusaur    Grass  Poison  80      82       83    100
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123    122
# 4      4             Charmander     Fire     NaN  39      52       43     60
# ..   ...                    ...      ...     ...  ..     ...      ...    ...
# 795  719                Diancie     Rock   Fairy  50     100      150    100
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110    160
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60    150
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60    170
# 799  721              Volcanion     Fire   Water  80     110      120    130
#
#      SpDef  Speed  Generation  Legendary
# ...

# %%
### Question 1) What are the last 37 Pokemon in the PokeDex?
import pandas
pokemon_data = pandas.read_csv('PokemonData.csv')
newest_25_pokemon = pokemon_data.tail(37)
newest_25_pokemon
# Out:
#      Num                   Name     Type1   Type2   HP  Attack  Defense  \
# 763  693              Clawitzer     Water     NaN   71      73       88
# 764  694             Helioptile  Electric  Normal   44      38       33
# 765  695              Heliolisk  Electric  Normal   62      55       52
# 766  696                 Tyrunt      Rock  Dragon   58      89       77
# 767  697              Tyrantrum      Rock  Dragon   82     121      119
# 768  698                 Amaura      Rock     Ice   77      59       50
# 769  699                Aurorus      Rock     Ice  123      77       72
# 770  700                Sylveon     Fairy     NaN   95      65       65
# 771  701               Hawlucha  Fighting  Flying   78      92       75
# 772  702                Dedenne  Electric   Fairy   67      58       57
# 773  703                Carbink      Rock   Fairy   50      50      150
# 774  704                  Goomy    Dragon     NaN   45      50       35
# ...

# %%
# Question) How many pokemon do not have a second typing?

import pandas
pokemon_data = pandas.read_csv('PokemonData.csv')
pokemon_type_missing = pokemon_data['Type2'].isnull().sum()
pokemon_type_missing
# Out:
# 386

# %%
# Question 3) What is the highest attack stat? 

import pandas
pokemon_data = pandas.read_csv('PokemonData.csv')

maxattack = pokemon_data['Attack'].max()
maxattack
# Out:
# 190

# %%
# Question 3) What is the minimum attack stat?

import pandas
pokemon_data = pandas.read_csv('PokemonData.csv')

minattack = pokemon_data['Attack'].min()
minattack
# Out:
# 5

# %%
pokemon_HA = pokemon_data.sort_values('Attack', ascending=False)
pokemon_HA
# Out:
#      Num                     Name    Type1     Type2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ..   ...                      ...      ...       ...  ...     ...      ...
# 139  129                 Magikarp    Water       NaN   20      10       55
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      SpAtk  SpDef  Speed  Generation  Legendary
# ...

# %%
pokemon_HD = pokemon_data.sort_values('Defense', ascending=False)
pokemon_HD
# Out:
#      Num                 Name     Type1   Type2   HP  Attack  Defense  SpAtk  \
# 230  213              Shuckle       Bug    Rock   20      10      230     10
# 224  208  SteelixMega Steelix     Steel  Ground   75     125      230     55
# 333  306    AggronMega Aggron     Steel     NaN   70     140      230     60
# 223  208              Steelix     Steel  Ground   75      85      200     55
# 414  377             Regirock      Rock     NaN   80     100      200     50
# ..   ...                  ...       ...     ...  ...     ...      ...    ...
# 68    63                 Abra   Psychic     NaN   25      20       15    105
# 186  172                Pichu  Electric     NaN   20      40       15     35
# 261  242              Blissey    Normal     NaN  255      10       10     75
# 488  440              Happiny    Normal     NaN  100       5        5     15
# 121  113              Chansey    Normal     NaN  250       5        5     35
#
#      SpDef  Speed  Generation  Legendary
# ...

# %%
pokemon_HP = pokemon_data.sort_values('HP', ascending=False)
pokemon_HP
# Out:
#      Num       Name    Type1  Type2   HP  Attack  Defense  SpAtk  SpDef  \
# 261  242    Blissey   Normal    NaN  255      10       10     75    135
# 121  113    Chansey   Normal    NaN  250       5        5     35    105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58     33     58
# 351  321    Wailord    Water    NaN  170      90       45     90     45
# 655  594  Alomomola    Water    NaN  165      75       80     40     45
# ..   ...        ...      ...    ...  ...     ...      ...    ...    ...
# 139  129   Magikarp    Water    NaN   20      10       55     15     20
# 381  349     Feebas    Water    NaN   20      15       20     10     55
# 388  355    Duskull    Ghost    NaN   20      40       90     30     90
# 55    50    Diglett   Ground    NaN   10      55       25     35     45
# 316  292   Shedinja      Bug  Ghost    1      90       45     30     30
#
#      Speed  Generation  Legendary
# 261     55           2      False
# ...

# %%
pokemon_defense = pokemon_data.sort_values('Defense', ascending=False)
pokemon_defense
# Out:
#      Num                 Name     Type1   Type2   HP  Attack  Defense  SpAtk  \
# 230  213              Shuckle       Bug    Rock   20      10      230     10
# 224  208  SteelixMega Steelix     Steel  Ground   75     125      230     55
# 333  306    AggronMega Aggron     Steel     NaN   70     140      230     60
# 223  208              Steelix     Steel  Ground   75      85      200     55
# 414  377             Regirock      Rock     NaN   80     100      200     50
# ..   ...                  ...       ...     ...  ...     ...      ...    ...
# 68    63                 Abra   Psychic     NaN   25      20       15    105
# 186  172                Pichu  Electric     NaN   20      40       15     35
# 261  242              Blissey    Normal     NaN  255      10       10     75
# 488  440              Happiny    Normal     NaN  100       5        5     15
# 121  113              Chansey    Normal     NaN  250       5        5     35
#
#      SpDef  Speed  Generation  Legendary
# ...

# %%
sns.lineplot(x = "Defense", y = "HP", data = pokemon_data)
# Out:
# <AxesSubplot: xlabel='Defense', ylabel='HP'>

# %%
# Calculate the average stats for each type of Pokemon
pokemon_data = pandas.read_csv('PokemonData.csv')
avg_stats = pokemon_data.groupby("Type1").mean()
print(avg_stats)
max_attack = pokemon_data["Attack"].max()
strongest_pokemon = pokemon_data[pokemon_data["Attack"] == max_attack]
print(strongest_pokemon)
# Out:
#                  Num         HP      Attack     Defense      SpAtk      SpDef  \
# Type1
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# ...

# %%
#Attack VS Defense

plt.scatter(pokemon_data["Attack"], pokemon_data["Defense"])
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.show()

# %%
from sklearn import tree
import pandas as pd
data = pokemon_data
clf = DecisionTreeClassifier()
test = pd.DataFrame({'Attack':[49],'Defense':[49],'Speed':[45]})
features = ['Attack', 'Defense', 'Speed']
clf = clf.fit(data[features], data['Type1'])
predictions = clf.predict(test[features])

print(predictions)
# Out:
# ['Grass']

# %%
from sklearn import tree
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
data = pokemon_data
test = pd.DataFrame({'HP':[95],'Attack':[135],'Defense':[80],'SpAtk':[110],'SpDef':[80],'Speed':[100]})
features = ['HP','Attack', 'Defense','SpAtk','SpDef','Speed']
clf = clf.fit(data[features], data['Name'])
#change data['anything you want to predict']
predictions = clf.predict(test[features])

print(predictions)
# Out:
# ['Salamence']
